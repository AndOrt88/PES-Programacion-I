# %% [markdown]
# ### Programa de Estudios Superiores 2019-2020
# ### Programación I - proyecto final
# #### Elaborado por <span class="alert alert-info"> ***Andrés Miguel Ortiz Flores*** </span><br>
# ***
# ***Instrucciones generales:*** resuelve el siguiente problema de acuerdo a la especificación dada.
# - El código debe ir comentado para explicar la lógica y debe ser totalmente funcional para ser considerado correcto. De lo contrario, la calificación podrá ser subjetiva.
# - Al final de la definición de la clase, obtenga una instancia y muestra que el objeto se comporta de acuerdo a las especificaciones deseadas, para poder calificarte más rápidamente.
# ***

# %% [markdown]
# # Estimador de desviación estándar *leave-one-out (LOO)*
#
# Considere un conjunto de datos $(x_{1i}, \ldots, x_{6i})$ y $y_i$, donde $i = 1, \ldots, n$. A partir de este conjunto, es posible estimar el modelo de regresión lineal:
#
# $$ y_i = \beta_0 + \beta_1 x_{1i} + \beta_2 x_{2i} + \beta_3 x_{3i}+ \beta_4 x_{4i}+ \beta_5 x_{5i}+ \beta_6 x_{6i}$$
#
# el cual puede expresarse en forma matricial como $y = X\beta$, donde $\beta$ corresponde al vector de parámetros del modelo.
#
# En cierta ocasión, un profesor de econometría se encontraba estudiando nuevas formas de obtener estimadores para la varianza de los parámetros muestrales. Después de mucho pensar, este ingenioso profesor resulta con un método de estimación denominado *leave-one-out estimator* (estimador de "deja uno afuera") que consiste en un proceso iterativo con el conjunto de datos:
#
# 1. Para cada $i$ en el conjunto de datos:
#
#     - Se elimina temporalmente la observación $i$ del conjunto para obtener el conjunto "modificado" $X_{-i}$.
#
#     - Se estima el modelo de regresión lineal resultante $y^* = X_{-i}\beta$
#
#     - Se guarda el resultado del parámetro $\beta^{(i)}$ de interés, donde $i$ denota que $\beta$ se estimó sin la observación $i$.
#
# 2. Al final del proceso iterativo, se estima la desviación estándar del conjunto $\lbrace\beta^{(1)}, ..., \beta^{(n)}\rbrace$ para obtener el estimador LOO del parámetro.
#
# A continuación, se muestra una imagen representativa del proceso iterativo sobre el conjunto de datos. En cada iteración, se estima con las muestras en blanco y se elimina temporalmente la observación en gris.
#
# ![Leave-One-Out-Cross-Validation.png](attachment:Leave-One-Out-Cross-Validation.png)
#
# Después de ocurrírsele este método al profesor, se dió cuenta que no sabía cómo llevar a cabo este proceso iterativo, ya que su habitual programa (software) de trabajo no permitía este tipo de procedimientos. Sin embargo, el profesor se recordó de su brillante amigo, que ha llevado recientemente un curso de programación en Python, y decide pedirle ayuda con esta tarea. Cuando el profesor contacta a su amigo, éste le dice que está muy cansado debido al curso que recién ha tomado, sin embargo, el profesor insiste en pedir su ayuda.
#
# Finalmente, después de recordar viejos tiempos y la invitación a un par de cervezas, el profesor logra convencer a su amigo de que lo ayude. Para esto, su amigo piensa resolver este problema a través de la implementación de una clase de Python.
#
# ## Descripción de la clase
#
# El amigo del profesor va a implementar la solución a través de la clase `looEstimation` de la siguiente forma:
#
# - Al crear un objeto de esta clase, el constructor debe recibir el conjunto de datos `data`, cuya primera columna será de unos, luego estarán las variables $x$ y finalmente, la última columna corresponde a la variable $y$.
#
# Además, deberá implementar los siguientes métodos:
#
# - Método `estimate`, que lleve a cabo el proceso de estimación sobre una matriz $X$ y vector $y$ para estimar todos los parámetros del modelo, los cuales devolverá como un arreglo de numpy.
#
# - Método `looSD`, que utilizará el método anterior sobre los datos guardados en el constructor y llevará a cabo el proceso iterativo $\lbrace\beta^{(1)}, ..., \beta^{(n)}\rbrace$. Finalmente, devolverá la desviación estándar del conjunto de parámetros.
#     - Se deben guardar los parámetros de cada iteración en alguna estructura (pandas o ndarray) para ser consumidos por los siguientes métodos.
#
# - Método `plotDistribution`, que realizará una gráfica del histograma para cada uno de los diferentes parámetros del modelo.
#     - Deberá agregar una opción booleana savePlots para escoger si guardar las gráficas en un formato de alta calidad (pdf, png).
#
# - Método `getParameters`, que devolverá un `DataFrame` con los parámetros estimados en cada iteración del proceso.
#     - Permite el parámetro booleano `saveCSV` para determinar si se debe guardar este `DataFrame` en un archivo CSV.

# %% [markdown]
# <div class="alert alert-info">
# <b>Importe los paquetes que sean necesarios</b>: <br>
#
#
# </div>

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn
import statsmodels.formula.api as sm

# %% [markdown]
# <div class="alert alert-info">
# <b>Escriba su código en la celda siguiente</b>: <br>
#
#
# </div>

# %%
class looEstimation:
    ''' 
        Recibe el conjunto de datos `data`, cuya primera columna será 
        de unos, luego estarán las variables $x$ y finalmente, la última
        columna corresponde a la variable $y$.
    '''
    #Se carga el archivo tipo ".npy" y lo convierte a un DataFrame
    np.load('data.npy')
    df = pd.DataFrame({ '1´s': data[0:50,0], 'x1': data[0:50,1], 'x2': data[0:50,2],'x3': data[0:50,3],'x4': data[0:50,4],'x5': data[0:50,5],'x6': data[0:50,6],'y': data[0:50,7]})
    
    def __init__(self, data):
        
        self.data = df
                
    '''
        lleve a cabo el proceso de estimación sobre una matriz $X$ y 
        vector $y$ para estimar todos los parámetros del modelo, los 
        cuales devolverá como un arreglo de numpy
    '''
    def estimate(self):
        result = sm.ols(formula='y ~ x1 + x2 + x3 + x4 + x5 + x6', data=df).fit()
        print(result.summary())
        return result.params
    
    '''
        Utiliza el método estimate sobre los datos guardados en el constructor 
        y llevará a cabo el proceso iterativo. Se deben guardar los parámetros 
        de cada iteración en alguna estructura (pandas o ndarray) para 
        ser consumidos por los siguientes métodos.
    '''
    def looSD(self):
        pass
    
    '''
        Realiza una gráfica del histograma para cada uno de los diferentes
        parámetros del modelo. La opción booleana savePlots sirve para escoger 
        si guardar las gráficas en un formato de alta calidad (pdf, png).
    '''
    def plotDistribution(self, savePlots=False):
        
        g=dflooSD.groupby('Intercept')["B1"]["B2"]["B3"]["B4"]["B5"]["B6"]
        g.plot(kind = "bar", color = "g")
        
        return
    
    
    '''
        Devuelve un `DataFrame` con los parámetros estimados en cada iteración 
        del proceso. Permite el parámetro booleano `saveCSV` para determinar si 
        se debe guardar este `DataFrame` en un archivo CSV.
    '''
    def getParameters(self):
        pass

# %% [markdown]
# ***
# ## Área de pruebas personal
#
# Utilice el siguiente espacio para llevar a cabo **sus** pruebas.

# %%
# Se proporciona el archivo de datos para trabajar
# (1's, x1, x2, x3, x4, x5, x6, y)
data = np.load('data.npy')
data.shape
# Out:
# (50, 8)

# %%
df = pd.DataFrame({ '1´s': data[0:50,0], 'x1': data[0:50,1], 'x2': data[0:50,2],'x3': data[0:50,3],'x4': data[0:50,4],'x5': data[0:50,5],'x6': data[0:50,6],'y': data[0:50,7]})

# %%
df
# Out:
#     1´s    x1    x2    x3        x4        x5        x6          y
# 0   1.0  16.0   1.0   3.0  5.718175  5.742968  3.624304  34.821257
# 1   1.0   5.0  19.0   0.0  7.216032  3.051358  9.017310  44.805892
# 2   1.0  11.0   3.0   5.0  5.354822  0.525216  8.023288  31.087359
# 3   1.0  19.0  18.0   0.0  1.503741  3.070216  9.538864  37.993154
# 4   1.0  19.0  13.0   0.0  2.817544  3.089195  0.485237  21.412420
# 5   1.0   3.0   0.0  11.0  6.937627  8.658586  8.203759  47.319769
# 6   1.0  13.0  19.0   3.0  1.524134  0.658181  4.706758  26.711993
# 7   1.0  13.0   0.0   0.0  9.663613  3.302648  2.049603  32.951088
# 8   1.0   2.0   8.0  15.0  8.862070  0.699296  9.240629  47.690221
# 9   1.0   4.0  12.0  11.0  9.520994  1.558143  0.291961  35.345688
# 10  1.0   3.0   2.0  11.0  7.947461  4.842449  8.151155  45.118837
# 11  1.0  17.0   7.0  11.0  5.523718  3.045762  5.155733  40.077530
# 12  1.0  10.0   7.0   5.0  4.933251  0.092834  1.141773  22.128783
# 13  1.0   8.0   2.0  13.0  2.155308  7.994517  6.528307  37.333317
# 14  1.0   3.0   0.0  18.0  3.223047  5.467985  6.630295  40.723234
# 15  1.0  14.0  12.0   4.0  9.332987  5.473666  1.241593  43.220836
# 16  1.0  13.0  13.0  16.0  2.625960  0.920071  1.560500  29.717604
# 17  1.0   1.0  19.0   9.0  5.837082  1.226263  6.635912  39.794083
# 18  1.0  17.0  10.0   7.0  3.489025  6.997158  8.644662  45.293524
# 19  1.0  14.0   7.0   0.0  0.062790  0.294461  4.791616  14.336555
# 20  1.0  15.0   3.0   6.0  5.175799  6.658746  2.654502  33.453347
# 21  1.0  11.0   6.0   1.0  9.467693  5.104885  6.549674  44.465261
# 22  1.0   3.0   0.0   4.0  3.582711  6.290217  0.577732  18.442775
# 23  1.0  16.0   5.0   3.0  0.651578  7.889200  4.912863  30.596809
# 24  1.0   1.0   2.0   8.0  7.921105  8.896315  2.674785  41.190983
# 25  1.0   2.0   0.0   4.0  6.303839  0.024409  9.570537  34.201991
# 26  1.0   3.0  17.0   5.0  4.068294  4.729967  1.623407  30.632955
# 27  1.0  18.0   5.0  13.0  3.731259  2.048565  3.029863  29.998444
# 28  1.0   6.0  16.0   1.0  7.747873  1.578920  9.310106  45.969186
# 29  1.0   1.0   2.0  11.0  3.996033  0.741192  5.655334  28.754483
# 30  1.0   2.0   3.0   0.0  9.113652  1.120706  9.087749  38.927951
# 31  1.0  11.0  15.0   3.0  5.624441  1.566043  4.700300  32.108011
# 32  1.0  16.0   0.0   1.0  2.081597  0.550870  3.268920  13.393719
# 33  1.0   5.0   0.0  11.0  7.573729  4.168661  5.423416  39.631611
# 34  1.0   7.0  16.0  19.0  8.234612  3.672349  8.143774  57.123836
# 35  1.0  11.0   3.0  16.0  1.911732  6.941344  7.875192  45.040257
# 36  1.0   7.0  10.0  14.0  4.088087  4.023513  0.500605  30.476774
# 37  1.0   9.0  10.0   1.0  0.350787  1.114894  4.554608  17.444661
# 38  1.0   0.0   3.0  18.0  1.773855  7.694683  9.242379  44.697836
# 39  1.0   6.0   9.0  14.0  8.525702  2.492404  4.309911  42.235804
# 40  1.0  14.0  15.0   9.0  0.009810  0.234581  1.498062  21.571744
# 41  1.0  13.0   7.0   4.0  7.440584  2.130331  6.239203  39.130589
# 42  1.0  14.0   4.0  19.0  3.745340  4.036158  3.501069  36.784944
# 43  1.0   3.0  16.0  19.0  2.662802  7.466088  1.713550  42.994115
# 44  1.0  14.0   2.0  14.0  8.641113  2.468610  6.667793  48.991011
# 45  1.0   3.0  13.0   5.0  2.197255  3.175513  3.024222  23.195772
# 46  1.0  17.0   4.0  10.0  5.341209  6.616901  6.512719  47.640444
# 47  1.0   5.0  13.0   1.0  7.550595  7.295056  8.866268  49.212016
# 48  1.0   2.0   4.0  12.0  0.354668  2.455803  2.494228  18.994648
# 49  1.0   8.0  16.0  19.0  6.711509  4.078057  8.378116  55.136326

# %%
result = sm.ols(formula='y ~ x1 + x2 + x3 + x4 + x5 + x6', data=df).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     390.5
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           8.07e-36
# Time:                        09:02:31   Log-Likelihood:                -87.836
# No. Observations:                  50   AIC:                             189.7
# Df Residuals:                      43   BIC:                             203.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6917      0.943     -0.733      0.467      -2.594       1.210
# x1             0.2851      0.040      7.162      0.000       0.205       0.365
# x2             0.4734      0.036     13.253      0.000       0.401       0.545
# x3             0.6713      0.037     18.297      0.000       0.597       0.745
# x4             2.0741      0.078     26.571      0.000       1.917       2.231
# x5             1.5274      0.086     17.690      0.000       1.353       1.702
# x6             1.7334      0.076     22.933      0.000       1.581       1.886
# ==============================================================================
# Omnibus:                        9.238   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                2.949
# Skew:                           0.188   Prob(JB):                        0.229
# Kurtosis:                       1.871   Cond. No.                         76.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
result.params
# Out:
# Intercept   -0.691715
# x1           0.285130
# x2           0.473372
# x3           0.671312
# x4           2.074063
# x5           1.527403
# x6           1.733444
# dtype: float64

# %%
result.params.values
# Out:
# array([-0.69171456,  0.28512965,  0.47337168,  0.67131171,  2.07406304,
#         1.52740284,  1.733444  ])

# %%
for index, row in df.iterrows():
    dfmin1=df.drop([index], axis=0)
    reslooSD = sm.ols(formula='y ~ x1 + x2 + x3 + x4 + x5 + x6', data=dfmin1).fit()
    print(reslooSD.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     392.2
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           3.24e-35
# Time:                        10:49:28   Log-Likelihood:                -85.897
# No. Observations:                  49   AIC:                             185.8
# Df Residuals:                      42   BIC:                             199.0
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7027      0.941     -0.747      0.460      -2.602       1.197
# x1             0.2783      0.040      6.920      0.000       0.197       0.359
# x2             0.4790      0.036     13.299      0.000       0.406       0.552
# x3             0.6757      0.037     18.342      0.000       0.601       0.750
# x4             2.0680      0.078     26.478      0.000       1.910       2.226
# x5             1.5164      0.087     17.478      0.000       1.341       1.691
# x6             1.7391      0.076     23.000      0.000       1.587       1.892
# ==============================================================================
# Omnibus:                        8.667   Durbin-Watson:                   2.103
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                3.015
# Skew:                           0.245   Prob(JB):                        0.221
# Kurtosis:                       1.888   Cond. No.                         75.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     375.9
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           7.75e-35
# Time:                        10:49:28   Log-Likelihood:                -86.565
# No. Observations:                  49   AIC:                             187.1
# Df Residuals:                      42   BIC:                             200.4
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6983      0.955     -0.731      0.469      -2.627       1.230
# x1             0.2845      0.041      7.020      0.000       0.203       0.366
# x2             0.4747      0.038     12.654      0.000       0.399       0.550
# x3             0.6703      0.038     17.672      0.000       0.594       0.747
# x4             2.0747      0.079     26.224      0.000       1.915       2.234
# x5             1.5281      0.087     17.465      0.000       1.351       1.705
# x6             1.7351      0.078     22.371      0.000       1.579       1.892
# ==============================================================================
# Omnibus:                       10.373   Durbin-Watson:                   2.120
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):                3.058
# Skew:                           0.184   Prob(JB):                        0.217
# Kurtosis:                       1.833   Cond. No.                         75.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     397.0
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           2.52e-35
# Time:                        10:49:28   Log-Likelihood:                -85.496
# No. Observations:                  49   AIC:                             185.0
# Df Residuals:                      42   BIC:                             198.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5908      0.936     -0.631      0.532      -2.481       1.299
# x1             0.2883      0.039      7.304      0.000       0.209       0.368
# x2             0.4653      0.036     12.985      0.000       0.393       0.538
# x3             0.6698      0.036     18.436      0.000       0.597       0.743
# x4             2.0724      0.077     26.820      0.000       1.916       2.228
# x5             1.5029      0.087     17.216      0.000       1.327       1.679
# x6             1.7503      0.076     23.086      0.000       1.597       1.903
# ==============================================================================
# Omnibus:                        6.757   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                2.521
# Skew:                           0.173   Prob(JB):                        0.284
# Kurtosis:                       1.944   Cond. No.                         75.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     382.0
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           5.58e-35
# Time:                        10:49:28   Log-Likelihood:                -86.521
# No. Observations:                  49   AIC:                             187.0
# Df Residuals:                      42   BIC:                             200.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6472      0.965     -0.671      0.506      -2.594       1.299
# x1             0.2823      0.041      6.831      0.000       0.199       0.366
# x2             0.4707      0.037     12.677      0.000       0.396       0.546
# x3             0.6729      0.037     17.968      0.000       0.597       0.748
# x4             2.0786      0.080     25.884      0.000       1.917       2.241
# x5             1.5260      0.087     17.461      0.000       1.350       1.702
# x6             1.7258      0.080     21.454      0.000       1.563       1.888
# ==============================================================================
# Omnibus:                        9.302   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                2.964
# Skew:                           0.199   Prob(JB):                        0.227
# Kurtosis:                       1.863   Cond. No.                         75.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     369.3
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           1.12e-34
# Time:                        10:49:28   Log-Likelihood:                -86.353
# No. Observations:                  49   AIC:                             186.7
# Df Residuals:                      42   BIC:                             199.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6583      0.952     -0.692      0.493      -2.579       1.262
# x1             0.2893      0.041      7.115      0.000       0.207       0.371
# x2             0.4757      0.036     13.149      0.000       0.403       0.549
# x3             0.6681      0.037     17.903      0.000       0.593       0.743
# x4             2.0729      0.079     26.357      0.000       1.914       2.232
# x5             1.5300      0.087     17.572      0.000       1.354       1.706
# x6             1.7244      0.078     22.244      0.000       1.568       1.881
# ==============================================================================
# Omnibus:                        9.180   Durbin-Watson:                   2.092
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                2.875
# Skew:                           0.171   Prob(JB):                        0.237
# Kurtosis:                       1.864   Cond. No.                         75.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     392.1
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           3.26e-35
# Time:                        10:49:28   Log-Likelihood:                -85.316
# No. Observations:                  49   AIC:                             184.6
# Df Residuals:                      42   BIC:                             197.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7215      0.930     -0.776      0.442      -2.599       1.156
# x1             0.2792      0.039      7.075      0.000       0.200       0.359
# x2             0.4671      0.035     13.168      0.000       0.396       0.539
# x3             0.6699      0.036     18.506      0.000       0.597       0.743
# x4             2.0780      0.077     26.979      0.000       1.923       2.233
# x5             1.5575      0.088     17.796      0.000       1.381       1.734
# x6             1.7452      0.075     23.282      0.000       1.594       1.896
# ==============================================================================
# Omnibus:                        7.575   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                2.601
# Skew:                           0.150   Prob(JB):                        0.272
# Kurtosis:                       1.912   Cond. No.                         75.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     375.7
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           7.84e-35
# Time:                        10:49:28   Log-Likelihood:                -86.537
# No. Observations:                  49   AIC:                             187.1
# Df Residuals:                      42   BIC:                             200.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7068      0.955     -0.740      0.464      -2.635       1.221
# x1             0.2848      0.040      7.072      0.000       0.204       0.366
# x2             0.4713      0.037     12.745      0.000       0.397       0.546
# x3             0.6720      0.037     18.068      0.000       0.597       0.747
# x4             2.0772      0.080     26.003      0.000       1.916       2.238
# x5             1.5295      0.088     17.443      0.000       1.353       1.706
# x6             1.7328      0.076     22.661      0.000       1.578       1.887
# ==============================================================================
# Omnibus:                        9.709   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                3.005
# Skew:                           0.195   Prob(JB):                        0.223
# Kurtosis:                       1.851   Cond. No.                         75.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     389.0
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           3.83e-35
# Time:                        10:49:28   Log-Likelihood:                -86.056
# No. Observations:                  49   AIC:                             186.1
# Df Residuals:                      42   BIC:                             199.4
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7678      0.948     -0.810      0.422      -2.680       1.145
# x1             0.2816      0.040      7.035      0.000       0.201       0.362
# x2             0.4801      0.036     13.167      0.000       0.407       0.554
# x3             0.6773      0.037     18.174      0.000       0.602       0.752
# x4             2.0527      0.081     25.243      0.000       1.889       2.217
# x5             1.5286      0.086     17.682      0.000       1.354       1.703
# x6             1.7483      0.077     22.622      0.000       1.592       1.904
# ==============================================================================
# Omnibus:                        9.847   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                3.142
# Skew:                           0.235   Prob(JB):                        0.208
# Kurtosis:                       1.852   Cond. No.                         76.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     382.2
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           5.52e-35
# Time:                        10:49:28   Log-Likelihood:                -85.890
# No. Observations:                  49   AIC:                             185.8
# Df Residuals:                      42   BIC:                             199.0
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7377      0.942     -0.783      0.438      -2.639       1.163
# x1             0.2819      0.040      7.077      0.000       0.202       0.362
# x2             0.4728      0.036     13.266      0.000       0.401       0.545
# x3             0.6789      0.037     18.220      0.000       0.604       0.754
# x4             2.0865      0.079     26.505      0.000       1.928       2.245
# x5             1.5058      0.088     17.032      0.000       1.327       1.684
# x6             1.7471      0.076     22.852      0.000       1.593       1.901
# ==============================================================================
# Omnibus:                        8.976   Durbin-Watson:                   2.095
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                2.796
# Skew:                           0.147   Prob(JB):                        0.247
# Kurtosis:                       1.867   Cond. No.                         75.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     384.5
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           4.86e-35
# Time:                        10:49:28   Log-Likelihood:                -86.375
# No. Observations:                  49   AIC:                             186.8
# Df Residuals:                      42   BIC:                             200.0
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6526      0.953     -0.685      0.497      -2.575       1.270
# x1             0.2826      0.040      7.005      0.000       0.201       0.364
# x2             0.4755      0.036     13.142      0.000       0.403       0.549
# x3             0.6733      0.037     18.135      0.000       0.598       0.748
# x4             2.0875      0.082     25.475      0.000       1.922       2.253
# x5             1.5218      0.088     17.385      0.000       1.345       1.698
# x6             1.7186      0.080     21.414      0.000       1.557       1.881
# ==============================================================================
# Omnibus:                        9.514   Durbin-Watson:                   2.100
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                2.906
# Skew:                           0.165   Prob(JB):                        0.234
# Kurtosis:                       1.854   Cond. No.                         75.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     383.7
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           5.10e-35
# Time:                        10:49:29   Log-Likelihood:                -86.049
# No. Observations:                  49   AIC:                             186.1
# Df Residuals:                      42   BIC:                             199.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6847      0.944     -0.725      0.472      -2.590       1.221
# x1             0.2818      0.040      7.043      0.000       0.201       0.363
# x2             0.4695      0.036     13.047      0.000       0.397       0.542
# x3             0.6722      0.037     18.296      0.000       0.598       0.746
# x4             2.0808      0.078     26.522      0.000       1.922       2.239
# x5             1.5287      0.086     17.684      0.000       1.354       1.703
# x6             1.7408      0.076     22.889      0.000       1.587       1.894
# ==============================================================================
# Omnibus:                        7.939   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                2.627
# Skew:                           0.134   Prob(JB):                        0.269
# Kurtosis:                       1.898   Cond. No.                         75.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     380.3
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           6.10e-35
# Time:                        10:49:29   Log-Likelihood:                -86.566
# No. Observations:                  49   AIC:                             187.1
# Df Residuals:                      42   BIC:                             200.4
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6773      0.961     -0.704      0.485      -2.618       1.263
# x1             0.2839      0.041      6.846      0.000       0.200       0.368
# x2             0.4735      0.036     13.100      0.000       0.401       0.546
# x3             0.6707      0.037     17.894      0.000       0.595       0.746
# x4             2.0733      0.079     26.170      0.000       1.913       2.233
# x5             1.5280      0.087     17.467      0.000       1.351       1.705
# x6             1.7332      0.076     22.656      0.000       1.579       1.888
# ==============================================================================
# Omnibus:                       10.063   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                3.053
# Skew:                           0.196   Prob(JB):                        0.217
# Kurtosis:                       1.842   Cond. No.                         75.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     371.2
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           1.00e-34
# Time:                        10:49:29   Log-Likelihood:                -86.326
# No. Observations:                  49   AIC:                             186.7
# Df Residuals:                      42   BIC:                             199.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.8222      0.970     -0.847      0.402      -2.780       1.136
# x1             0.2858      0.040      7.128      0.000       0.205       0.367
# x2             0.4751      0.036     13.178      0.000       0.402       0.548
# x3             0.6722      0.037     18.186      0.000       0.598       0.747
# x4             2.0725      0.079     26.362      0.000       1.914       2.231
# x5             1.5384      0.089     17.377      0.000       1.360       1.717
# x6             1.7433      0.078     22.477      0.000       1.587       1.900
# ==============================================================================
# Omnibus:                        9.524   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                3.048
# Skew:                           0.218   Prob(JB):                        0.218
# Kurtosis:                       1.859   Cond. No.                         77.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     398.6
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           2.32e-35
# Time:                        10:49:29   Log-Likelihood:                -85.507
# No. Observations:                  49   AIC:                             185.0
# Df Residuals:                      42   BIC:                             198.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6635      0.934     -0.710      0.481      -2.548       1.221
# x1             0.2842      0.039      7.211      0.000       0.205       0.364
# x2             0.4689      0.036     13.203      0.000       0.397       0.541
# x3             0.6736      0.036     18.524      0.000       0.600       0.747
# x4             2.0558      0.078     26.213      0.000       1.898       2.214
# x5             1.5507      0.087     17.792      0.000       1.375       1.727
# x6             1.7423      0.075     23.196      0.000       1.591       1.894
# ==============================================================================
# Omnibus:                        8.262   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                2.674
# Skew:                           0.135   Prob(JB):                        0.263
# Kurtosis:                       1.888   Cond. No.                         75.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     397.5
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           2.45e-35
# Time:                        10:49:29   Log-Likelihood:                -85.475
# No. Observations:                  49   AIC:                             184.9
# Df Residuals:                      42   BIC:                             198.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.8169      0.938     -0.871      0.389      -2.709       1.075
# x1             0.2912      0.040      7.348      0.000       0.211       0.371
# x2             0.4816      0.036     13.440      0.000       0.409       0.554
# x3             0.6626      0.037     17.989      0.000       0.588       0.737
# x4             2.0890      0.078     26.790      0.000       1.932       2.246
# x5             1.5264      0.085     17.868      0.000       1.354       1.699
# x6             1.7259      0.075     23.019      0.000       1.575       1.877
# ==============================================================================
# Omnibus:                        6.971   Durbin-Watson:                   2.079
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):                2.879
# Skew:                           0.282   Prob(JB):                        0.237
# Kurtosis:                       1.955   Cond. No.                         75.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     391.7
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           3.33e-35
# Time:                        10:49:29   Log-Likelihood:                -85.694
# No. Observations:                  49   AIC:                             185.4
# Df Residuals:                      42   BIC:                             198.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5442      0.945     -0.576      0.568      -2.451       1.363
# x1             0.2782      0.040      6.962      0.000       0.198       0.359
# x2             0.4668      0.036     13.008      0.000       0.394       0.539
# x3             0.6745      0.037     18.452      0.000       0.601       0.748
# x4             2.0435      0.081     25.109      0.000       1.879       2.208
# x5             1.5089      0.087     17.325      0.000       1.333       1.685
# x6             1.7567      0.077     22.688      0.000       1.600       1.913
# ==============================================================================
# Omnibus:                        6.634   Durbin-Watson:                   2.135
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                2.571
# Skew:                           0.202   Prob(JB):                        0.276
# Kurtosis:                       1.953   Cond. No.                         75.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     378.8
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           6.62e-35
# Time:                        10:49:29   Log-Likelihood:                -86.556
# No. Observations:                  49   AIC:                             187.1
# Df Residuals:                      42   BIC:                             200.4
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6945      0.954     -0.728      0.471      -2.620       1.231
# x1             0.2843      0.041      7.017      0.000       0.203       0.366
# x2             0.4728      0.036     13.028      0.000       0.400       0.546
# x3             0.6696      0.038     17.461      0.000       0.592       0.747
# x4             2.0747      0.079     26.252      0.000       1.915       2.234
# x5             1.5301      0.089     17.268      0.000       1.351       1.709
# x6             1.7354      0.077     22.473      0.000       1.580       1.891
# ==============================================================================
# Omnibus:                        9.716   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                3.017
# Skew:                           0.199   Prob(JB):                        0.221
# Kurtosis:                       1.851   Cond. No.                         74.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     380.8
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           5.94e-35
# Time:                        10:49:29   Log-Likelihood:                -86.545
# No. Observations:                  49   AIC:                             187.1
# Df Residuals:                      42   BIC:                             200.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6826      0.955     -0.715      0.479      -2.609       1.244
# x1             0.2833      0.041      6.903      0.000       0.201       0.366
# x2             0.4754      0.037     12.758      0.000       0.400       0.551
# x3             0.6714      0.037     18.095      0.000       0.597       0.746
# x4             2.0741      0.079     26.277      0.000       1.915       2.233
# x5             1.5255      0.088     17.392      0.000       1.349       1.703
# x6             1.7342      0.077     22.665      0.000       1.580       1.889
# ==============================================================================
# Omnibus:                       10.534   Durbin-Watson:                   2.076
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):                3.065
# Skew:                           0.179   Prob(JB):                        0.216
# Kurtosis:                       1.828   Cond. No.                         75.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     381.9
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           5.61e-35
# Time:                        10:49:29   Log-Likelihood:                -86.146
# No. Observations:                  49   AIC:                             186.3
# Df Residuals:                      42   BIC:                             199.5
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.8663      0.968     -0.895      0.376      -2.819       1.086
# x1             0.2931      0.041      7.151      0.000       0.210       0.376
# x2             0.4763      0.036     13.235      0.000       0.404       0.549
# x3             0.6709      0.037     18.230      0.000       0.597       0.745
# x4             2.0695      0.078     26.373      0.000       1.911       2.228
# x5             1.5434      0.089     17.424      0.000       1.365       1.722
# x6             1.7482      0.078     22.493      0.000       1.591       1.905
# ==============================================================================
# Omnibus:                        9.956   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                2.921
# Skew:                           0.146   Prob(JB):                        0.232
# Kurtosis:                       1.840   Cond. No.                         76.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     353.1
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           2.82e-34
# Time:                        10:49:29   Log-Likelihood:                -86.176
# No. Observations:                  49   AIC:                             186.4
# Df Residuals:                      42   BIC:                             199.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4950      0.976     -0.507      0.615      -2.464       1.474
# x1             0.2859      0.040      7.153      0.000       0.205       0.367
# x2             0.4704      0.036     13.060      0.000       0.398       0.543
# x3             0.6664      0.037     17.863      0.000       0.591       0.742
# x4             2.0568      0.081     25.377      0.000       1.893       2.220
# x5             1.5150      0.088     17.228      0.000       1.338       1.692
# x6             1.7371      0.076     22.859      0.000       1.584       1.891
# ==============================================================================
# Omnibus:                        7.430   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                2.596
# Skew:                           0.158   Prob(JB):                        0.273
# Kurtosis:                       1.918   Cond. No.                         77.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     386.1
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           4.46e-35
# Time:                        10:49:29   Log-Likelihood:                -86.247
# No. Observations:                  49   AIC:                             186.5
# Df Residuals:                      42   BIC:                             199.7
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6983      0.948     -0.737      0.465      -2.611       1.215
# x1             0.2892      0.040      7.162      0.000       0.208       0.371
# x2             0.4712      0.036     13.083      0.000       0.399       0.544
# x3             0.6699      0.037     18.139      0.000       0.595       0.744
# x4             2.0774      0.079     26.436      0.000       1.919       2.236
# x5             1.5385      0.088     17.477      0.000       1.361       1.716
# x6             1.7266      0.077     22.566      0.000       1.572       1.881
# ==============================================================================
# Omnibus:                        8.488   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                2.722
# Skew:                           0.143   Prob(JB):                        0.256
# Kurtosis:                       1.881   Cond. No.                         75.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     376.5
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           7.50e-35
# Time:                        10:49:29   Log-Likelihood:                -86.553
# No. Observations:                  49   AIC:                             187.1
# Df Residuals:                      42   BIC:                             200.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...
# Skew:                           0.122   Prob(JB):                        0.235
# Kurtosis:                       1.834   Cond. No.                         74.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     415.4
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           9.93e-36
# Time:                        10:49:29   Log-Likelihood:                -84.297
# No. Observations:                  49   AIC:                             182.6
# Df Residuals:                      42   BIC:                             195.8
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6743      0.911     -0.740      0.463      -2.513       1.164
# x1             0.2971      0.039      7.637      0.000       0.219       0.376
# x2             0.4539      0.036     12.675      0.000       0.382       0.526
# x3             0.6571      0.036     18.189      0.000       0.584       0.730
# x4             2.0884      0.076     27.579      0.000       1.936       2.241
# x5             1.4863      0.086     17.317      0.000       1.313       1.660
# x6             1.7635      0.074     23.671      0.000       1.613       1.914
# ==============================================================================
# Omnibus:                        6.336   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                2.327
# Skew:                           0.105   Prob(JB):                        0.312
# Kurtosis:                       1.953   Cond. No.                         74.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     390.0
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           3.64e-35
# Time:                        10:49:29   Log-Likelihood:                -85.255
# No. Observations:                  49   AIC:                             184.5
# Df Residuals:                      42   BIC:                             197.8
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4693      0.940     -0.499      0.620      -2.367       1.428
# x1             0.2708      0.040      6.717      0.000       0.189       0.352
# x2             0.4811      0.036     13.536      0.000       0.409       0.553
# x3             0.6592      0.037     17.815      0.000       0.585       0.734
# x4             2.0481      0.079     26.007      0.000       1.889       2.207
# x5             1.5456      0.086     17.998      0.000       1.372       1.719
# x6             1.7254      0.075     23.118      0.000       1.575       1.876
# ==============================================================================
# Omnibus:                        6.191   Durbin-Watson:                   2.184
# Prob(Omnibus):                  0.045   Jarque-Bera (JB):                2.615
# Skew:                           0.245   Prob(JB):                        0.270
# Kurtosis:                       1.980   Cond. No.                         75.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     375.0
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           8.14e-35
# Time:                        10:49:29   Log-Likelihood:                -86.215
# No. Observations:                  49   AIC:                             186.4
# Df Residuals:                      42   BIC:                             199.7
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5119      0.974     -0.525      0.602      -2.478       1.455
# x1             0.2777      0.041      6.757      0.000       0.195       0.361
# x2             0.4764      0.036     13.203      0.000       0.404       0.549
# x3             0.6676      0.037     17.966      0.000       0.593       0.743
# x4             2.0637      0.079     25.959      0.000       1.903       2.224
# x5             1.5286      0.087     17.623      0.000       1.354       1.704
# x6             1.7270      0.076     22.615      0.000       1.573       1.881
# ==============================================================================
# Omnibus:                        8.311   Durbin-Watson:                   1.830
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                2.754
# Skew:                           0.170   Prob(JB):                        0.252
# Kurtosis:                       1.890   Cond. No.                         77.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     398.3
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           2.36e-35
# Time:                        10:49:29   Log-Likelihood:                -84.904
# No. Observations:                  49   AIC:                             183.8
# Df Residuals:                      42   BIC:                             197.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4116      0.937     -0.439      0.663      -2.302       1.479
# x1             0.2683      0.040      6.683      0.000       0.187       0.349
# x2             0.4765      0.035     13.623      0.000       0.406       0.547
# x3             0.6670      0.036     18.543      0.000       0.594       0.740
# x4             2.0672      0.076     27.044      0.000       1.913       2.221
# x5             1.5064      0.085     17.658      0.000       1.334       1.679
# x6             1.7218      0.074     23.197      0.000       1.572       1.872
# ==============================================================================
# Omnibus:                        6.995   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                2.691
# Skew:                           0.224   Prob(JB):                        0.260
# Kurtosis:                       1.943   Cond. No.                         76.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     370.0
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           1.08e-34
# Time:                        10:49:29   Log-Likelihood:                -86.493
# No. Observations:                  49   AIC:                             187.0
# Df Residuals:                      42   BIC:                             200.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7245      0.957     -0.757      0.453      -2.655       1.206
# x1             0.2836      0.040      7.014      0.000       0.202       0.365
# x2             0.4759      0.037     12.966      0.000       0.402       0.550
# x3             0.6679      0.038     17.513      0.000       0.591       0.745
# x4             2.0763      0.079     26.258      0.000       1.917       2.236
# x5             1.5367      0.091     16.942      0.000       1.354       1.720
# x6             1.7376      0.077     22.519      0.000       1.582       1.893
# ==============================================================================
# Omnibus:                        9.869   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                2.967
# Skew:                           0.172   Prob(JB):                        0.227
# Kurtosis:                       1.845   Cond. No.                         75.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     360.9
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           1.79e-34
# Time:                        10:49:29   Log-Likelihood:                -86.537
# No. Observations:                  49   AIC:                             187.1
# Df Residuals:                      42   BIC:                             200.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7794      1.014     -0.769      0.446      -2.826       1.267
# x1             0.2877      0.042      6.932      0.000       0.204       0.371
# x2             0.4746      0.036     13.031      0.000       0.401       0.548
# x3             0.6710      0.037     18.078      0.000       0.596       0.746
# x4             2.0796      0.082     25.392      0.000       1.914       2.245
# x5             1.5299      0.088     17.412      0.000       1.353       1.707
# x6             1.7358      0.077     22.554      0.000       1.580       1.891
# ==============================================================================
# Omnibus:                       10.285   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):                3.114
# Skew:                           0.208   Prob(JB):                        0.211
# Kurtosis:                       1.837   Cond. No.                         80.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     364.3
# Date:                Fri, 17 Jan 2020   Prob (F-statistic):           1.48e-34
# Time:                        10:49:29   Log-Likelihood:                -85.937
# No. Observations:                  49   AIC:                             185.9
# Df Residuals:                      42   BIC:                             199.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9635      0.977     -0.986      0.330      -2.935       1.008
# x1             0.2891      0.040      7.239      0.000       0.208       0.370
# x2             0.4823      0.037     13.154      0.000       0.408       0.556
# x3             0.6828      0.038     17.858      0.000       0.606       0.760
# x4             2.0822      0.078     26.577      0.000       1.924       2.240
# x5             1.5281      0.086     17.720      0.000       1.354       1.702
# x6             1.7459      0.076     22.848      0.000       1.592       1.900
# ==============================================================================
# Omnibus:                       12.395   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                3.197
# Skew:                           0.147   Prob(JB):                        0.202
# Kurtosis:                       1.783   Cond. No.                         76.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
for index, row in df.iterrows():
    dfmin1=df.drop([index], axis=0)
    reslooSD = sm.ols(formula='y ~ x1 + x2 + x3 + x4 + x5 + x6', data=dfmin1).fit()
    print(reslooSD.params.values)
# Out:
# [-0.70271448  0.27831498  0.47896714  0.67569743  2.06795334  1.51640107
#   1.73909175]
# [-0.69825266  0.2845345   0.474676    0.67030114  2.07468817  1.52806186
#   1.73512474]
# [-0.59082542  0.28832672  0.46532238  0.66983526  2.07242831  1.50291976
#   1.75030682]
# [-0.64716941  0.28227976  0.47073752  0.67289317  2.07859644  1.52597541
#   1.72581749]
# [-0.65831221  0.28926363  0.47573083  0.66812134  2.07290743  1.530023
#   1.72444141]
# [-0.72153995  0.27918892  0.46711963  0.66986009  2.07801256  1.55753959
#   1.74520716]
# [-0.70682282  0.28479214  0.47134     0.67199235  2.07721606  1.52950372
#   1.73278555]
# [-0.76777866  0.28161675  0.48014939  0.67725802  2.0527445   1.52863318
#   1.7483096 ]
# [-0.73769546  0.28190301  0.47283582  0.67885626  2.08654157  1.50575759
#   1.74709664]
# [-0.65255226  0.28261658  0.47553513  0.6732693   2.08750125  1.52180018
#   1.71864218]
# [-0.68466835  0.28177359  0.46949976  0.67222046  2.08075925  1.52865334
#   1.74076022]
# [-0.67732141  0.28392416  0.47347079  0.67067944  2.0732884   1.52798803
#   1.73317757]
# [-0.8221847   0.2857701   0.47507904  0.67215931  2.07250764  1.53842295
#   1.74326979]
# [-0.66350226  0.28422778  0.46887586  0.67360774  2.05577994  1.55065632
#   1.74234501]
# [-0.81689406  0.29118059  0.48164085  0.66262492  2.08903921  1.52640449
#   1.72593581]
# [-0.54421904  0.27818027  0.46682849  0.67447031  2.04354698  1.50890973
#   1.75671856]
# [-0.6945208   0.28432801  0.47276547  0.66959891  2.07468591  1.53005634
#   1.73536746]
# [-0.68264057  0.2833409   0.47542251  0.67140871  2.07412398  1.52552522
#   1.73423612]
# [-0.8662989   0.29305846  0.47628754  0.67093055  2.06952377  1.54341172
#   1.74815747]
# [-0.4949628   0.28588114  0.47044652  0.66636246  2.05681797  1.51499486
#   1.73714261]
# [-0.69825585  0.28924407  0.47120217  0.66985151  2.07744094  1.53851692
#   1.72660671]
# [-0.70609641  0.28569043  0.47325389  0.67013881  2.07745337  1.52927198
#   1.7338686 ]
# [-0.09024731  0.26674603  0.46187994  0.65734992  2.06047157  1.55105327
#   1.69631114]
# [-0.70153286  0.28374434  0.47378783  0.67314501  2.0792717   1.5201025
#   1.73238834]
# [-0.73919453  0.28909741  0.47446838  0.67342311  2.06926394  1.51524208
#   1.74108281]
# [-1.01633004  0.29565978  0.48660465  0.67754592  2.07895848  1.56068593
#   1.71038918]
# [-0.75233461  0.28901423  0.46969436  0.67345437  2.07553122  1.5221627
#   1.74023993]
# [-0.72976155  0.29699583  0.4695495   0.67991611  2.07510036  1.51393157
#   1.72834036]
# [-0.63772582  0.28919759  0.46381717  0.67977627  2.06378305  1.53458274
#   1.7125815 ]
# [-0.9918907   0.29490792  0.48109183  0.66969715  2.08439043  1.55015962
#   1.73205204]
# [-0.83147482  0.2917054   0.47850062  0.67873154  2.06561461  1.53983218
#   1.72305926]
# [-0.67788253  0.28625635  0.47917972  0.66804413  2.07837381  1.52173525
#   1.73186341]
# [-0.35224888  0.29077217  0.45990616  0.66485682  2.05897005  1.50313429
#   1.72949554]
# [-0.6933813   0.28518732  0.4735254   0.67127351  2.07386045  1.52746442
#   1.73349504]
# [-0.95051193  0.28831148  0.48156659  0.682043    2.0877435   1.52602554
#   1.74258045]
# [-0.5847178   0.27915193  0.47788679  0.66201059  2.09552031  1.51062486
#   1.7121439 ]
# [-0.66421767  0.28438007  0.47407708  0.67275538  2.07410149  1.52781515
#   1.72768262]
# [-0.66267274  0.28463758  0.47333917  0.67058081  2.07171558  1.52634453
#   1.73361759]
# [-0.71023857  0.28772106  0.47420647  0.66979505  2.08087353  1.52292232
#   1.72811729]
# [-0.72809612  0.28483921  0.47455648  0.6769969   2.08888099  1.51984699
#   1.72717311]
# [-0.89163611  0.2814454   0.46693874  0.6666915   2.09782269  1.54966493
#   1.74687897]
# [-0.67748117  0.28315838  0.4739091   0.67200163  2.06976891  1.53017826
#   1.73185958]
# [-0.74493996  0.2913329   0.47093166  0.68048883  2.07385045  1.52378386
#   1.73017968]
# [-0.674343    0.29713228  0.45393454  0.65711506  2.08837581  1.48632114
#   1.7634605 ]
# [-0.46932813  0.27082616  0.4810589   0.65918669  2.04807033  1.54560119
#   1.72542503]
# [-0.51190511  0.27766367  0.47640579  0.66757222  2.06370481  1.52863477
#   1.72697405]
# [-0.41163838  0.26828788  0.47645954  0.66697071  2.06718915  1.50640327
#   1.72180814]
# [-0.72447192  0.28357147  0.47589377  0.66794259  2.07628692  1.53673131
#   1.73761412]
# [-0.77937567  0.2877037   0.47456996  0.67100251  2.07963399  1.52994955
#   1.73575676]
# [-0.96348361  0.28909575  0.48227226  0.68279529  2.08224462  1.52808758
#   1.74589806]

# %%
arr = np.array([])
for index, row in df.iterrows():
    dfmin1=df.drop([index], axis=0)
    reslooSD = sm.ols(formula='y ~ x1 + x2 + x3 + x4 + x5 + x6', data=dfmin1).fit()
    arr = np.column_stack((arr, reslooSD.params.values))
print(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-304ecde0f08e> in <module>
# ----> 1 arr = np.array([],7)
#       2 for index, row in df.iterrows():
#       3     dfmin1=df.drop([index], axis=0)
#       4     reslooSD = sm.ols(formula='y ~ x1 + x2 + x3 + x4 + x5 + x6', data=dfmin1).fit()
#       5     arr = np.column_stack((arr, reslooSD.params.values))
#
# TypeError: data type not understood

# %%
for index, row in df.iterrows():
    dflooSD = pd.DataFrame(columns=['Intercept', 'B1', 'B2','B3','B4','B5','B6'])
    dfmin1=df.drop([index], axis=0)
    reslooSD = sm.ols(formula='y ~ x1 + x2 + x3 + x4 + x5 + x6', data=dfmin1).fit()
    dflooSD = dflooSD.append({"Intercept" : reslooSD.params.values[0] ,"B1" : reslooSD.params.values[1],"B2" : reslooSD.params.values[2],"B3" : reslooSD.params.values[3],"B4" : reslooSD.params.values[3],"B5" : reslooSD.params.values[4],"B6" : reslooSD.params.values[5]}, ignore_index=True)
    
    print(dflooSD )
# Out:
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.702714  0.278315  0.478967  0.675697  0.675697  2.067953  1.516401
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.698253  0.284534  0.474676  0.670301  0.670301  2.074688  1.528062
#    Intercept        B1        B2        B3        B4        B5       B6
# 0  -0.590825  0.288327  0.465322  0.669835  0.669835  2.072428  1.50292
#    Intercept       B1        B2        B3        B4        B5        B6
# 0  -0.647169  0.28228  0.470738  0.672893  0.672893  2.078596  1.525975
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.658312  0.289264  0.475731  0.668121  0.668121  2.072907  1.530023
#    Intercept        B1       B2       B3       B4        B5       B6
# 0   -0.72154  0.279189  0.46712  0.66986  0.66986  2.078013  1.55754
#    Intercept        B1       B2        B3        B4        B5        B6
# 0  -0.706823  0.284792  0.47134  0.671992  0.671992  2.077216  1.529504
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.767779  0.281617  0.480149  0.677258  0.677258  2.052744  1.528633
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.737695  0.281903  0.472836  0.678856  0.678856  2.086542  1.505758
#    Intercept        B1        B2        B3        B4        B5      B6
# 0  -0.652552  0.282617  0.475535  0.673269  0.673269  2.087501  1.5218
#    Intercept        B1      B2       B3       B4        B5        B6
# 0  -0.684668  0.281774  0.4695  0.67222  0.67222  2.080759  1.528653
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.677321  0.283924  0.473471  0.670679  0.670679  2.073288  1.527988
#    Intercept       B1        B2        B3        B4        B5        B6
# 0  -0.822185  0.28577  0.475079  0.672159  0.672159  2.072508  1.538423
#    Intercept        B1        B2        B3        B4       B5        B6
# 0  -0.663502  0.284228  0.468876  0.673608  0.673608  2.05578  1.550656
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.816894  0.291181  0.481641  0.662625  0.662625  2.089039  1.526404
#    Intercept       B1        B2       B3       B4        B5       B6
# 0  -0.544219  0.27818  0.466828  0.67447  0.67447  2.043547  1.50891
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.694521  0.284328  0.472765  0.669599  0.669599  2.074686  1.530056
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.682641  0.283341  0.475423  0.671409  0.671409  2.074124  1.525525
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.866299  0.293058  0.476288  0.670931  0.670931  2.069524  1.543412
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.494963  0.285881  0.470447  0.666362  0.666362  2.056818  1.514995
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.698256  0.289244  0.471202  0.669852  0.669852  2.077441  1.538517
#    Intercept       B1        B2        B3        B4        B5        B6
# 0  -0.706096  0.28569  0.473254  0.670139  0.670139  2.077453  1.529272
#    Intercept        B1       B2       B3       B4        B5        B6
# 0  -0.090247  0.266746  0.46188  0.65735  0.65735  2.060472  1.551053
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.701533  0.283744  0.473788  0.673145  0.673145  2.079272  1.520102
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.739195  0.289097  0.474468  0.673423  0.673423  2.069264  1.515242
#    Intercept       B1        B2        B3        B4        B5        B6
# 0   -1.01633  0.29566  0.486605  0.677546  0.677546  2.078958  1.560686
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.752335  0.289014  0.469694  0.673454  0.673454  2.075531  1.522163
#    Intercept        B1        B2        B3        B4      B5        B6
# 0  -0.729762  0.296996  0.469549  0.679916  0.679916  2.0751  1.513932
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.637726  0.289198  0.463817  0.679776  0.679776  2.063783  1.534583
#    Intercept        B1        B2        B3        B4       B5       B6
# 0  -0.991891  0.294908  0.481092  0.669697  0.669697  2.08439  1.55016
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.831475  0.291705  0.478501  0.678732  0.678732  2.065615  1.539832
#    Intercept        B1       B2        B3        B4        B5        B6
# 0  -0.677883  0.286256  0.47918  0.668044  0.668044  2.078374  1.521735
#    Intercept        B1        B2        B3        B4       B5        B6
# 0  -0.352249  0.290772  0.459906  0.664857  0.664857  2.05897  1.503134
#    Intercept        B1        B2        B3        B4       B5        B6
# 0  -0.693381  0.285187  0.473525  0.671274  0.671274  2.07386  1.527464
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.950512  0.288311  0.481567  0.682043  0.682043  2.087743  1.526026
#    Intercept        B1        B2        B3        B4       B5        B6
# 0  -0.584718  0.279152  0.477887  0.662011  0.662011  2.09552  1.510625
#    Intercept       B1        B2        B3        B4        B5        B6
# 0  -0.664218  0.28438  0.474077  0.672755  0.672755  2.074101  1.527815
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.662673  0.284638  0.473339  0.670581  0.670581  2.071716  1.526345
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.710239  0.287721  0.474206  0.669795  0.669795  2.080874  1.522922
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.728096  0.284839  0.474556  0.676997  0.676997  2.088881  1.519847
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.891636  0.281445  0.466939  0.666691  0.666691  2.097823  1.549665
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.677481  0.283158  0.473909  0.672002  0.672002  2.069769  1.530178
#    Intercept        B1        B2        B3        B4       B5        B6
# 0   -0.74494  0.291333  0.470932  0.680489  0.680489  2.07385  1.523784
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.674343  0.297132  0.453935  0.657115  0.657115  2.088376  1.486321
#    Intercept        B1        B2        B3        B4       B5        B6
# 0  -0.469328  0.270826  0.481059  0.659187  0.659187  2.04807  1.545601
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.511905  0.277664  0.476406  0.667572  0.667572  2.063705  1.528635
#    Intercept        B1       B2        B3        B4        B5        B6
# 0  -0.411638  0.268288  0.47646  0.666971  0.666971  2.067189  1.506403
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.724472  0.283571  0.475894  0.667943  0.667943  2.076287  1.536731
#    Intercept        B1       B2        B3        B4        B5       B6
# 0  -0.779376  0.287704  0.47457  0.671003  0.671003  2.079634  1.52995
#    Intercept        B1        B2        B3        B4        B5        B6
# 0  -0.963484  0.289096  0.482272  0.682795  0.682795  2.082245  1.528088

# %%
dflooSD["B1"].std()
# Out:
# nan

# %%
dflooSD['B1'].hist()

# %% [markdown]
# ***
# ## Área de pruebas para calificación
#
# Utilice el siguiente espacio para mostrarnos su implementación terminada.

# %% [markdown]
# <div class="alert alert-info">
# <b>Pruebe el método "estimate"</b>: <br>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Pruebe el método "looSD"</b>: <br>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Pruebe el método "plotDistribution"</b>: <br>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Pruebe el método "getParameters"</b>: <br>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Muestre cada uno de los atribujos del objeto utilizado en el ejemplo</b>: <br>
# </div>
